# %% [markdown]
# # MAGMOM used in DFT for Ba$_2$YOsO$_6$

# %%
import itertools as its
import numpy as np
    
FistSpinConf = np.array([[-2.121, -2.121, 0], [-2.121, 2.121, 0], [2.121, -2.121, 0], [2.121, 2.121, 0]])
SpinPermutation=list(its.permutations(FistSpinConf, 4))
# a

# %%
f=open('24MAGMOM.txt', 'w')
for x in SpinPermutation:
    print('MAGMOM = 24*0 12*0', sep=' ', end=' ')
    print('MAGMOM = 24*0 12*0', sep=' ', end=' ', file=f)
    for y in x:
        for z in y:
            print(z, sep=' ', end=' ')
            print(z, sep=' ', end=' ', file=f)
    print('72*0')
    print('72*0', file=f)
        
f.close()
# Out:
# MAGMOM = 24*0 12*0 -2.121 -2.121 0.0 -2.121 2.121 0.0 2.121 -2.121 0.0 2.121 2.121 0.0 72*0
# MAGMOM = 24*0 12*0 -2.121 -2.121 0.0 -2.121 2.121 0.0 2.121 2.121 0.0 2.121 -2.121 0.0 72*0
# MAGMOM = 24*0 12*0 -2.121 -2.121 0.0 2.121 -2.121 0.0 -2.121 2.121 0.0 2.121 2.121 0.0 72*0
# MAGMOM = 24*0 12*0 -2.121 -2.121 0.0 2.121 -2.121 0.0 2.121 2.121 0.0 -2.121 2.121 0.0 72*0
# MAGMOM = 24*0 12*0 -2.121 -2.121 0.0 2.121 2.121 0.0 -2.121 2.121 0.0 2.121 -2.121 0.0 72*0
# MAGMOM = 24*0 12*0 -2.121 -2.121 0.0 2.121 2.121 0.0 2.121 -2.121 0.0 -2.121 2.121 0.0 72*0
# MAGMOM = 24*0 12*0 -2.121 2.121 0.0 -2.121 -2.121 0.0 2.121 -2.121 0.0 2.121 2.121 0.0 72*0
# MAGMOM = 24*0 12*0 -2.121 2.121 0.0 -2.121 -2.121 0.0 2.121 2.121 0.0 2.121 -2.121 0.0 72*0
# MAGMOM = 24*0 12*0 -2.121 2.121 0.0 2.121 -2.121 0.0 -2.121 -2.121 0.0 2.121 2.121 0.0 72*0
# MAGMOM = 24*0 12*0 -2.121 2.121 0.0 2.121 -2.121 0.0 2.121 2.121 0.0 -2.121 -2.121 0.0 72*0
# ...

# %% [markdown]
# # testing

# %%
import itertools as its
import numpy as np
    
FistSpinConf = np.array([[-2.121, 2.121, 0], [2.121, -2.121, 0], [-2.121, -2.121, 0], [2.121, 2.121, 0]])
SpinPermutation=list(its.permutations(FistSpinConf, 4)) #The starting is coplanar-twoin-twoout,

# %%
f=open('24MAGMOM.txt', 'w')
for x in SpinPermutation:
    print('MAGMOM = 24*0 12*0', sep=' ', end=' ')
    print('MAGMOM = 24*0 12*0', sep=' ', end=' ', file=f)
    for y in x:
        for z in y:
            print(z, sep=' ', end=' ')
            print(z, sep=' ', end=' ', file=f)
    print('72*0')
    print('72*0', file=f)
        
f.close()
# Out:
# MAGMOM = 24*0 12*0 -2.121 2.121 0.0 2.121 -2.121 0.0 -2.121 -2.121 0.0 2.121 2.121 0.0 72*0
# MAGMOM = 24*0 12*0 -2.121 2.121 0.0 2.121 -2.121 0.0 2.121 2.121 0.0 -2.121 -2.121 0.0 72*0
# MAGMOM = 24*0 12*0 -2.121 2.121 0.0 -2.121 -2.121 0.0 2.121 -2.121 0.0 2.121 2.121 0.0 72*0
# MAGMOM = 24*0 12*0 -2.121 2.121 0.0 -2.121 -2.121 0.0 2.121 2.121 0.0 2.121 -2.121 0.0 72*0
# MAGMOM = 24*0 12*0 -2.121 2.121 0.0 2.121 2.121 0.0 2.121 -2.121 0.0 -2.121 -2.121 0.0 72*0
# MAGMOM = 24*0 12*0 -2.121 2.121 0.0 2.121 2.121 0.0 -2.121 -2.121 0.0 2.121 -2.121 0.0 72*0
# MAGMOM = 24*0 12*0 2.121 -2.121 0.0 -2.121 2.121 0.0 -2.121 -2.121 0.0 2.121 2.121 0.0 72*0
# MAGMOM = 24*0 12*0 2.121 -2.121 0.0 -2.121 2.121 0.0 2.121 2.121 0.0 -2.121 -2.121 0.0 72*0
# MAGMOM = 24*0 12*0 2.121 -2.121 0.0 -2.121 -2.121 0.0 -2.121 2.121 0.0 2.121 2.121 0.0 72*0
# MAGMOM = 24*0 12*0 2.121 -2.121 0.0 -2.121 -2.121 0.0 2.121 2.121 0.0 -2.121 2.121 0.0 72*0
# ...

# %%
import pandas as pd
from pandas import Series

a = Series([1,2,3])
a
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64
